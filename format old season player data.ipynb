# %% [markdown]
# # 16/17, 17/18, 18/19 players data had more columns than succeeding seasons we're removing them one by one

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import namedtuple
import random
from random import sample
from collections import Counter
import numba
import os
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
path1617 = "/home/pratik/Documents/MSc/Project/Data Preparation/2018-19/players"
dir_list_1617 = os.listdir(path1617)
print('\n'.join(dir_list_1617))
# Out:
# Denis_Suárez_586
# Scott_Malone_196
# David_De Gea_282
# Lucas_Pérez_502
# Chris_Smalling_284
# Alex_Pritchard_206
# Martin_Dubravka_309
# Alex_McCarthy_328
# Lewis_Dunk_48
# James_McArthur_147
# Florent_Hadergjonaj_197
# Ryan_Babel_575
# Reece_Oxford_407
# Sam_Surridge_599
# Yves_Bissouma_466
# Jason_Puncheon_146
# Wes_Morgan_215
# Harvey_Elliott_610
# Xherdan_Shaqiri_462
# Brahim_Diaz_278
# Isaac_Hayden_323
# Loïc_Damour_104
# Gary_Madine_109
# Joseph_Willock_566
# Georginio_Wijnaldum_252
# Hugo_Lloris_351
# Neil_Etheridge_88
# Declan_Rice_406
# Roberto_Firmino_257
# Yerry_Mina_506
# Matej_Vydra_495
# Karlan_Grant_585
# Joshua_Sims_342
# Alexandre_Lacazette_22
# Anthony_Knockaert_55
# Oliver_Skipp_540
# Matteo_Darmian_289
# Ryan_Bertrand_330
# José_Holebas_378
# Aaron_Cresswell_402
# Stephan_Lichtsteiner_11
# Andy_Carroll_418
# Ramadan_Sobhi_207
# Nathaniel_Chalobah_387
# Charlie_Taylor_74
# James_Milner_254
# Marc_Albrighton_224
# Jonathan_Walters_81
# Loris_Karius_238
# ...

# %%
for item in dir_list_1617:
    itempath = path1617 + "/" +str(item)+ "/gw.csv"
    itemdf = pd.read_csv(itempath)
    itemdf.head()
    itemdf = itemdf.drop(['attempted_passes','big_chances_created','big_chances_missed','clearances_blocks_interceptions','completed_passes','dribbles','ea_index','errors_leading_to_goal','errors_leading_to_goal_attempt','fouls','id','key_passes','kickoff_time_formatted','loaned_in','loaned_out','offside','open_play_crosses','penalties_conceded','recoveries','tackled','tackles','target_missed','winning_goals'], axis = 1)
    itemdf.to_csv(itempath,index=False)
